# %% [markdown]
# <a href="https://colab.research.google.com/github/VanNguyenThiCam/Code-Math/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Vẽ đồ thị***

# %%
import matplotlib.pyplot as plt

# %%
x_data = [0,1,2,3,4,5]
y_data = [2,3,4,7,4,3]

# %%
plt.plot(x_data,y_data)
plt.ylabel('y values')
plt.xlabel('x values')
# Out:
# Text(0.5, 0, 'x values')

# %% [markdown]
# ***Hiển thị hình bằng plt***

# %%
import matplotlib.pyplot as plt 
import cv2

# %%
from google.colab import drive #cách lấy dữ liệu trên google.colab 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img = cv2.imread('/content/gdrive/MyDrive/Colab Notebooks/OpenCv/a.png')

# %%
plt.figure(figsize=(6,6))
plt.imshow(img)
plt.show()

# %% [markdown]
# ***Cách khác biệt hiển thị hình giữa Opencv và Matplotlib***
#
#
#
# 1. **Hệ màu**: opencv bgr; matplotlib rgb
# 2. **Ứng dụng**: matplotlib thì nó có 2 trục, xử lý tính toán, chuyên về visualization
# opencv chủ yếu xử lý hình ảnh và video

# %%
img_bgr = cv2.imread('/content/gdrive/MyDrive/Colab Notebooks/OpenCv/a.png')
im_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(6,6))
plt.imshow(im_rgb)
plt.show()
